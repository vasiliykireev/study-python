# %% [markdown]
# # Задание 1
# С помощью python смоделировать игру против лотерейного автомата типа «777».
#
# Игрок платит 1 руб., после чего выпадает случайное целое число, равномерно распределенное от 0 до 999.
# При некоторых значениях числа игрок получает выигрыш:
# 777: 200 рублей
# 999: 100 рублей
# 555: 50 рублей
# 333: 15 рублей
# 111: 10 рублей
# **7: 3 рубля
# *00: 2 рубля
# **0: 1 рубль
# (* – любая цифра)
# Выгодна ли игра игроку?
# Сколько в среднем приобретает или теряет игрок за одну игру?

# %%
import random

class Game:

    def __init__(self):
        self._score = self.stavochka()

    @property
    def score(self):
        return self._score

    def stavochka(self, debug=None):
        """
        Игра в автомат

        Аргументы:
        - debug (int): число для отладки

        Возвращает str: 3 цифры
        """
        if debug is not None:
            result = debug
            if debug > 999:
                return 'error'
        else:
            result = random.randint(0, 999)

        result = str(result)
        zeros_number = 3 - len(result)
        string = '0' * zeros_number
        result = string + result

        return result

g = Game()
print(g.score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 36
#      33         return result
#      35 g = Game()
# ---> 36 print(g.winnings)
#
# AttributeError: 'Game' object has no attribute 'winnings'
