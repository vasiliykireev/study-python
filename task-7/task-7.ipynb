# %% [markdown]
# # Задание 1
#
# Загрузите из CSV-файла исходные данные о покупателях с веб-портала (до 15 строк). При необходимости преобразуйте данные. С помощью Seaborn и Plotly сформируйте диаграмму разброса зависимости возраста клиента от расходов (scatterplot).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# Загрузим до 15 строк
df = pd.read_csv("web_clients_correct.csv", nrows=16)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Fontconfig warning: ignoring C.UTF-8: not a valid language tag
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 24
#      21 spend_col = find_column(df, ["spend", "expense", "amount", "cost", "purchase", "total", "расход", "сумма"])
#      23 if age_col is None or spend_col is None:
# ---> 24     raise ValueError(f"Не найдены столбцы возраста или расходов. Найдено age: {age_col}, spend: {spend_col}")
#      26 # Преобразуем в числовой тип и отбросим пропуски
#      27 df = df[[age_col, spend_col]].copy()
#
# ValueError: Не найдены столбцы возраста или расходов. Найдено age: age, spend: None

# %% [markdown]
# # Задание 2
#
# Загрузите из CSV-файла исходные данные о покупателях с веб-портала (до 15 строк). При необходимости преобразуйте данные. С помощью Seaborn сформируйте линию регрессии к диаграмме рассеяния (regplot).
